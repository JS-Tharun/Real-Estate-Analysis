# %% [markdown]
# # Real Estate Analysis

# %% [markdown]
# ## Importing Libraries and Datasets

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import pandas as pd
import mysql.connector
import sqlite3
from dotenv import load_dotenv
import matplotlib.pyplot as plt
from tabulate import tabulate
from decimal import Decimal, ROUND_HALF_UP
import seaborn as sns
import matplotlib.ticker as ticker
import numpy as np

# %%
# Creating dataframes
agents_df = pd.read_json('Datasets/agents_cleaned.json')
buyers_df = pd.read_json('Datasets/buyers_cleaned.json')
listings_df = pd.read_json('Datasets/listings_final_expanded.json')
prop_att_df = pd.read_json('Datasets/property_attributes_final_expanded.json')
sales_df = pd.read_csv('Datasets/sales_cleaned.csv')

# %% [markdown]
# ## Data Preparation and Cleaning

# %%
# Percentage of missing values
def per_miss_val(df):
  return 100 * df.isnull().sum() / len(df)

# Rounding to 2 decimals
def round_decimals(x):
  value = Decimal(x)
  rounded = value.quantize(Decimal('0.01'), rounding=ROUND_HALF_UP)
  return rounded

# %% [markdown]
# ### Agents Dataset

# %%
# First 5 rows
agents_df.head()
# Out:
#   Agent_ID         Name            Phone                 Email  \
# 0    A0001  Agent A0001  +1-534-665-8373  a0001@realestate.com
# 1    A0002  Agent A0002  +1-493-463-4698  a0002@realestate.com
# 2    A0003  Agent A0003  +1-290-534-1121  a0003@realestate.com
# 3    A0004  Agent A0004  +1-691-610-4878  a0004@realestate.com
# 4    A0005  Agent A0005  +1-829-613-5411  a0005@realestate.com
#
#    commission_rate  deals_closed  rating  experience_years  avg_closing_days
# 0             2.00            52     4.3                10                64
# 1             2.20            26     3.8                20                82
# 2             2.85           297     3.6                21                83
# 3             1.67            31     4.5                 5                61
# 4             1.11           198     4.3                16                67

# %%
# Last 5 rows
agents_df.tail()
# Out:
#    Agent_ID         Name            Phone                 Email  \
# 45    A0046  Agent A0046  +1-873-939-2900  a0046@realestate.com
# 46    A0047  Agent A0047  +1-153-271-8602  a0047@realestate.com
# 47    A0048  Agent A0048  +1-508-587-5937  a0048@realestate.com
# 48    A0049  Agent A0049  +1-587-864-9724  a0049@realestate.com
# 49    A0050  Agent A0050  +1-339-488-7390  a0050@realestate.com
#
#     commission_rate  deals_closed  rating  experience_years  avg_closing_days
# 45             1.57           135     3.2                10                58
# 46             1.63            91     4.0                16                33
# 47             1.34           266     4.0                21                15
# 48             1.70            17     4.1                14                33
# 49             2.56           109     3.5                11                68

# %%
# Basic Information
agents_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Agent_ID          50 non-null     object
#  1   Name              50 non-null     object
#  2   Phone             50 non-null     object
#  3   Email             50 non-null     object
#  4   commission_rate   50 non-null     float64
#  5   deals_closed      50 non-null     int64
#  6   rating            50 non-null     float64
#  7   experience_years  50 non-null     int64
#  8   avg_closing_days  50 non-null     int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 3.6+ KB

# %%
# Removing "Name" column
agents_df.drop(columns='Name', inplace=True)
agents_df.head()
# Out:
#   Agent_ID            Phone                 Email  commission_rate  \
# 0    A0001  +1-534-665-8373  a0001@realestate.com             2.00
# 1    A0002  +1-493-463-4698  a0002@realestate.com             2.20
# 2    A0003  +1-290-534-1121  a0003@realestate.com             2.85
# 3    A0004  +1-691-610-4878  a0004@realestate.com             1.67
# 4    A0005  +1-829-613-5411  a0005@realestate.com             1.11
#
#    deals_closed  rating  experience_years  avg_closing_days
# 0            52     4.3                10                64
# 1            26     3.8                20                82
# 2           297     3.6                21                83
# 3            31     4.5                 5                61
# 4           198     4.3                16                67

# %%
# Formatting the phone number
from re import split

def format_number(st):
  split_lst = st.split('-')
  phone_number = ''
  for i in split_lst:
    phone_number += i
  #country_code = split_lst[0].replace('+','')
  #phone_number = ''
  #for i in range(1, len(split_lst)):
    #phone_number += split_lst[i]

  return phone_number

#agents_df['Country Code'] = agents_df.Phone.apply(lambda x: format_number(x)[0]).astype(int)
agents_df['Phone'] = agents_df.Phone.apply(lambda x: format_number(x))
agents_df = agents_df[
  ['Agent_ID', 'Email', 'Phone', 'commission_rate', 'deals_closed', 'rating', 'experience_years', 'avg_closing_days']
  ]
agents_df.head()
# Out:
#   Agent_ID                 Email         Phone  commission_rate  deals_closed  \
# 0    A0001  a0001@realestate.com  +15346658373             2.00            52
# 1    A0002  a0002@realestate.com  +14934634698             2.20            26
# 2    A0003  a0003@realestate.com  +12905341121             2.85           297
# 3    A0004  a0004@realestate.com  +16916104878             1.67            31
# 4    A0005  a0005@realestate.com  +18296135411             1.11           198
#
#    rating  experience_years  avg_closing_days
# 0     4.3                10                64
# 1     3.8                20                82
# 2     3.6                21                83
# 3     4.5                 5                61
# 4     4.3                16                67

# %%
# Missing values
per_miss_val(agents_df)
# Out:
# Agent_ID            0.0
# Email               0.0
# Phone               0.0
# commission_rate     0.0
# deals_closed        0.0
# rating              0.0
# experience_years    0.0
# avg_closing_days    0.0
# dtype: float64

# %%
# Summary Statistics
agents_df.describe(include='all')
# Out:
#        Agent_ID                 Email         Phone  commission_rate  \
# count        50                    50            50        50.000000
# unique       50                    50            50              NaN
# top       A0001  a0001@realestate.com  +15346658373              NaN
# freq          1                     1             1              NaN
# mean        NaN                   NaN           NaN         2.051400
# std         NaN                   NaN           NaN         0.513996
# min         NaN                   NaN           NaN         1.110000
# 25%         NaN                   NaN           NaN         1.640000
# 50%         NaN                   NaN           NaN         1.985000
# 75%         NaN                   NaN           NaN         2.507500
# max         NaN                   NaN           NaN         2.960000
#
#         deals_closed     rating  experience_years  avg_closing_days
# count      50.000000  50.000000         50.000000         50.000000
# ...

# %% [markdown]
# ### Property Attributes Dataset

# %%
# First 5 rows
prop_att_df.head()
# Out:
#    attribute_id listing_id  bedrooms  bathrooms  floor_number  total_floors  \
# 0             1     L00001         5          3             9             9
# 1             2     L00002         2          2            19            29
# 2             3     L00003         2          3             8            26
# 3             4     L00004         3          3            25            10
# 4             5     L00005         2          2            15            16
#
#    year_built  is_rented  tenant_count furnishing_status  metro_distance_km  \
# 0        2001       True             4         Furnished               7.26
# 1        2020      False             0       Unfurnished               4.84
# 2        2007       True             4    Semi-Furnished               4.92
# 3        2003      False             3         Furnished               1.20
# 4        2008       True             1    Semi-Furnished               7.90
#
#    parking_available  power_backup
# ...

# %%
# Last 5 rows
prop_att_df.tail()
# Out:
#        attribute_id listing_id  bedrooms  bathrooms  floor_number  \
# 21195         21196     L21196         5          4             3
# 21196         21197     L21197         5          1             0
# 21197         21198     L21198         5          2             7
# 21198         21199     L21199         5          3            20
# 21199         21200     L21200         4          2             9
#
#        total_floors  year_built  is_rented  tenant_count furnishing_status  \
# 21195             6        2018       True             2    Semi-Furnished
# 21196            33        2010      False             0       Unfurnished
# 21197            29        1992       True             4    Semi-Furnished
# 21198            21        2013      False             0    Semi-Furnished
# 21199            30        2019       True             3         Furnished
#
#        metro_distance_km  parking_available  power_backup
# 21195               6.21               True          True
# ...

# %%
# Basic Information
prop_att_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21200 entries, 0 to 21199
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   attribute_id       21200 non-null  int64
#  1   listing_id         21200 non-null  object
#  2   bedrooms           21200 non-null  int64
#  3   bathrooms          21200 non-null  int64
#  4   floor_number       21200 non-null  int64
#  5   total_floors       21200 non-null  int64
#  6   year_built         21200 non-null  int64
#  7   is_rented          21200 non-null  bool
#  8   tenant_count       21200 non-null  int64
#  9   furnishing_status  21200 non-null  object
#  10  metro_distance_km  21200 non-null  float64
#  11  parking_available  21200 non-null  bool
#  12  power_backup       21200 non-null  bool
# dtypes: bool(3), float64(1), int64(7), object(2)
# memory usage: 1.7+ MB

# %%
# Maintaining consistency with Column Name
prop_att_df.rename(columns={'listing_id': 'Listing_ID'}, inplace=True)
prop_att_df.head()
# Out:
#    attribute_id Listing_ID  bedrooms  bathrooms  floor_number  total_floors  \
# 0             1     L00001         5          3             9             9
# 1             2     L00002         2          2            19            29
# 2             3     L00003         2          3             8            26
# 3             4     L00004         3          3            25            10
# 4             5     L00005         2          2            15            16
#
#    year_built  is_rented  tenant_count furnishing_status  metro_distance_km  \
# 0        2001       True             4         Furnished               7.26
# 1        2020      False             0       Unfurnished               4.84
# 2        2007       True             4    Semi-Furnished               4.92
# 3        2003      False             3         Furnished               1.20
# 4        2008       True             1    Semi-Furnished               7.90
#
#    parking_available  power_backup
# ...

# %%
# Summary statistics
prop_att_df.describe(include='all')
# Out:
#         attribute_id Listing_ID      bedrooms     bathrooms  floor_number  \
# count   21200.000000      21200  21200.000000  21200.000000  21200.000000
# unique           NaN      21200           NaN           NaN           NaN
# top              NaN     L00001           NaN           NaN           NaN
# freq             NaN          1           NaN           NaN           NaN
# mean    10600.500000        NaN      3.003726      2.497877      9.636274
# std      6120.057189        NaN      1.414059      1.119787      8.529010
# min         1.000000        NaN      1.000000      1.000000      0.000000
# 25%      5300.750000        NaN      2.000000      1.000000      3.000000
# 50%     10600.500000        NaN      3.000000      2.000000      7.000000
# 75%     15900.250000        NaN      4.000000      4.000000     15.000000
# max     21200.000000        NaN      5.000000      4.000000     38.000000
#
#         total_floors    year_built is_rented  tenant_count furnishing_status  \
# ...

# %% [markdown]
# ### Buyers Dataset

# %%
# First 5 rows
buyers_df.head()
# Out:
#    buyer_id sale_id buyer_type   payment_mode  loan_taken loan_provider  \
# 0         1  L01179   End User           Cash       False          None
# 1         2  L00866   Investor         Cheque       False          None
# 2         3  L00102   Investor         Cheque        True          Axis
# 3         4  L00440   Investor  Bank Transfer       False          None
# 4         5  L00059   Investor            UPI        True          HDFC
#
#    loan_amount
# 0            0
# 1            0
# 2      2317757
# 3            0
# 4      4191221

# %%
# Last 5 rows
buyers_df.tail()
# Out:
#        buyer_id sale_id buyer_type payment_mode  loan_taken loan_provider  \
# 19995     19996  L00891   Investor          UPI       False          None
# 19996     19997  L00834   End User          UPI       False          None
# 19997     19998  L01188   Investor          UPI       False          None
# 19998     19999  L00905   Investor       Cheque        True         ICICI
# 19999     20000  L00526   Investor         Cash        True           SBI
#
#        loan_amount
# 19995            0
# 19996            0
# 19997            0
# 19998      3701968
# 19999      3805678

# %%
# Basic Information
buyers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   buyer_id       20000 non-null  int64
#  1   sale_id        20000 non-null  object
#  2   buyer_type     20000 non-null  object
#  3   payment_mode   20000 non-null  object
#  4   loan_taken     20000 non-null  bool
#  5   loan_provider  10034 non-null  object
#  6   loan_amount    20000 non-null  int64
# dtypes: bool(1), int64(2), object(4)
# memory usage: 957.2+ KB

# %%
# Percentage of missing values
per_miss_val(buyers_df)
# Out:
# buyer_id          0.00
# sale_id           0.00
# buyer_type        0.00
# payment_mode      0.00
# loan_taken        0.00
# loan_provider    49.83
# loan_amount       0.00
# dtype: float64

# %%
# Checking if the loan provider is null for the buyer who has not taken a loan
buyers_df[buyers_df['loan_taken'] == False]['loan_provider'].unique()
# Out:
# array([None], dtype=object)

# %%
# Checking if there are any loan amounts entered, for loan not taken
buyers_df[buyers_df['loan_amount'] == False]['loan_amount'].unique()
# Out:
# array([0])

# %%
# Fill null values with "NA"
buyers_df['loan_provider'] = buyers_df['loan_provider'].fillna('NA')
buyers_df.head()
# Out:
#    buyer_id sale_id buyer_type   payment_mode  loan_taken loan_provider  \
# 0         1  L01179   End User           Cash       False            NA
# 1         2  L00866   Investor         Cheque       False            NA
# 2         3  L00102   Investor         Cheque        True          Axis
# 3         4  L00440   Investor  Bank Transfer       False            NA
# 4         5  L00059   Investor            UPI        True          HDFC
#
#    loan_amount
# 0            0
# 1            0
# 2      2317757
# 3            0
# 4      4191221

# %%
# Percentage of null values
per_miss_val(buyers_df)
# Out:
# buyer_id         0.0
# sale_id          0.0
# buyer_type       0.0
# payment_mode     0.0
# loan_taken       0.0
# loan_provider    0.0
# loan_amount      0.0
# dtype: float64

# %%
# Changing 'sale_id' column name to 'Listing_ID' to maintain consistency
buyers_df.rename(columns={'sale_id':'Listing_ID', 'payment_mode': 'Payment_Method'}, inplace=True)
buyers_df.head()
# Out:
#    buyer_id Listing_ID buyer_type Payment_Method  loan_taken loan_provider  \
# 0         1     L01179   End User           Cash       False            NA
# 1         2     L00866   Investor         Cheque       False            NA
# 2         3     L00102   Investor         Cheque        True          Axis
# 3         4     L00440   Investor  Bank Transfer       False            NA
# 4         5     L00059   Investor            UPI        True          HDFC
#
#    loan_amount
# 0            0
# 1            0
# 2      2317757
# 3            0
# 4      4191221

# %%
# Summary Statistics
buyers_df.describe(include='all')
# Out:
#             buyer_id Listing_ID buyer_type Payment_Method loan_taken  \
# count   20000.000000      20000      20000          20000      20000
# unique           NaN        720          2              4          2
# top              NaN     L01179   End User           Cash       True
# freq             NaN         28      10020           5088      10034
# mean    10000.500000        NaN        NaN            NaN        NaN
# std      5773.647028        NaN        NaN            NaN        NaN
# min         1.000000        NaN        NaN            NaN        NaN
# 25%      5000.750000        NaN        NaN            NaN        NaN
# 50%     10000.500000        NaN        NaN            NaN        NaN
# 75%     15000.250000        NaN        NaN            NaN        NaN
# max     20000.000000        NaN        NaN            NaN        NaN
#
#        loan_provider   loan_amount
# count          20000  2.000000e+04
# unique             6           NaN
# ...

# %% [markdown]
# ### Listings Dataset|

# %%
# First 5 rows
listings_df.head()
# Out:
#   Listing_ID         City Property_Type         Price         Sqft  \
# 0     L00001     New York     Apartment  1.655144e+06  2753.009121
# 1     L00002  Los Angeles     Apartment  1.519141e+06  4966.988193
# 2     L00003      Houston     Apartment  1.624890e+05  1267.003959
# 3     L00004      Phoenix     Apartment  1.277016e+06  2128.014429
# 4     L00005      Phoenix     Townhouse  5.622970e+05  4178.997421
#
#   Date_Listed Agent_ID   Latitude   Longitude
# 0  2023-05-06    A0015  33.965208  -69.861589
# 1  2023-02-14    A0038  42.547892  -90.277860
# 2  2023-04-22    A0015  28.732327 -115.952982
# 3  2024-01-02    A0042  26.403938  -74.771490
# 4  2023-10-29    A0018  39.425252  -83.917878

# %%
# Last 5 rows
listings_df.tail()
# Out:
#       Listing_ID         City Property_Type       Price     Sqft Date_Listed  \
# 21195     L21196      Phoenix         House   709355.28   898.41  2023-12-31
# 21196     L21197      Phoenix         Condo  3288420.13  4195.68  2023-07-23
# 21197     L21198  Los Angeles     Apartment  1667441.24  8723.37  2024-06-30
# 21198     L21199  Los Angeles     Townhouse  1648411.61  8412.71  2023-09-17
# 21199     L21200     New York     Apartment  4991528.39  3994.92  2023-07-28
#
#       Agent_ID   Latitude   Longitude
# 21195    A0021  25.456929  -88.189857
# 21196    A0005  40.926232  -80.167341
# 21197    A0003  46.083306 -115.396164
# 21198    A0018  33.757737 -103.472564
# 21199    A0008  42.222541 -119.219408

# %%
# Percentage of missing values
print("Percentage of missing values")
per_miss_val(listings_df)
# Out:
# Percentage of missing values
# Listing_ID       0.0
# City             0.0
# Property_Type    0.0
# Price            0.0
# Sqft             0.0
# Date_Listed      0.0
# Agent_ID         0.0
# Latitude         0.0
# Longitude        0.0
# dtype: float64

# %%
# Basic Information
listings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21200 entries, 0 to 21199
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Listing_ID     21200 non-null  object
#  1   City           21200 non-null  object
#  2   Property_Type  21200 non-null  object
#  3   Price          21200 non-null  float64
#  4   Sqft           21200 non-null  float64
#  5   Date_Listed    21200 non-null  object
#  6   Agent_ID       21200 non-null  object
#  7   Latitude       21200 non-null  float64
#  8   Longitude      21200 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 1.5+ MB

# %%
# Rounding float values in 'Price' and 'Sqft' columns
listings_df['Price'] = listings_df['Price'].apply(lambda x: round_decimals(x)).astype(float)
listings_df['Sqft'] = listings_df['Sqft'].apply(lambda x: round_decimals(x)).astype(float)

# %%
# Summary Statistics
listings_df.describe(include='all')
# Out:
#        Listing_ID         City Property_Type         Price          Sqft  \
# count       21200        21200         21200  2.120000e+04  21200.000000
# unique      21200            5             4           NaN           NaN
# top        L00001  Los Angeles         Condo           NaN           NaN
# freq            1         4318          5363           NaN           NaN
# mean          NaN          NaN           NaN  2.452708e+06   5113.376097
# std           NaN          NaN           NaN  1.419864e+06   2737.677578
# min           NaN          NaN           NaN  1.000271e+05    500.010000
# 25%           NaN          NaN           NaN  1.216681e+06   2768.277500
# 50%           NaN          NaN           NaN  2.383803e+06   4974.845000
# 75%           NaN          NaN           NaN  3.679127e+06   7488.895000
# max           NaN          NaN           NaN  4.999864e+06   9999.590000
#
#        Date_Listed Agent_ID      Latitude     Longitude
# ...

# %% [markdown]
# ### Sales Dataset

# %%
# First 5 rows
sales_df.head()
# Out:
#   Listing_ID    Sale_Price   Date_Sold  Days_on_Market
# 0     L01179  9.255800e+05  2023-07-07       65.005560
# 1     L00866  1.054160e+05  2023-06-14       38.004620
# 2     L00102  1.825184e+06  2023-09-09       22.992622
# 3     L00440  1.932085e+06  2023-10-29       72.012274
# 4     L00059  7.765860e+05  2023-05-01      116.000152

# %%
# Last 5 rows
sales_df.tail()
# Out:
#     Listing_ID    Sale_Price   Date_Sold  Days_on_Market
# 715     L00691  2.820920e+05  2024-06-18      101.992142
# 716     L00545  1.917896e+06  2023-12-16       33.006934
# 717     L01123  1.294670e+06  2023-06-21       45.996047
# 718     L00675  1.398092e+06  2024-04-15       49.998021
# 719     L00690  5.039320e+05  2023-05-13      118.997563

# %%
# Rounding the Days_on_Market column to the nearest integer
sales_df['Days_on_Market'] = sales_df['Days_on_Market'].apply(lambda x: round(x))
sales_df.head()
# Out:
#   Listing_ID    Sale_Price   Date_Sold  Days_on_Market
# 0     L01179  9.255800e+05  2023-07-07              65
# 1     L00866  1.054160e+05  2023-06-14              38
# 2     L00102  1.825184e+06  2023-09-09              23
# 3     L00440  1.932085e+06  2023-10-29              72
# 4     L00059  7.765860e+05  2023-05-01             116

# %%
# Basic Information
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Listing_ID      720 non-null    object
#  1   Sale_Price      720 non-null    float64
#  2   Date_Sold       720 non-null    object
#  3   Days_on_Market  720 non-null    int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 22.6+ KB

# %%
# Summary Statistics
sales_df.describe()
# Out:
#          Sale_Price  Days_on_Market
# count  7.200000e+02      720.000000
# mean   1.077546e+06       61.641667
# std    5.427902e+05       34.118699
# min    1.054160e+05        5.000000
# 25%    6.031483e+05       30.750000
# 50%    1.076570e+06       63.000000
# 75%    1.532235e+06       91.000000
# max    2.077611e+06      120.000000

# %% [markdown]
# ## Connecting to MySQL

# %%
load_dotenv()

conn = mysql.connector.connect(
  host = os.getenv('MYSQL_HOST'),
  user=os.getenv('MYSQL_USER'),
  password=os.getenv('MYSQL_PASSWORD')
)

cur = conn.cursor()

# %% [markdown]
# ## Creating a Database 'Real_Estate'

# %%
# Deleting if database exists
cur.execute("drop database if exists Real_Estate")

db_name = 'Real_Estate'

try:
  cur.execute("show databases like %s", (db_name,))
  result = cur.fetchone()


  if result:
    print(f"Database '{db_name}' already exists.")

  else:
    cur.execute(f'create database {db_name}')
    print(f"Database '{db_name}' created successfully.")

except Exception as e:
  print("Error Creating database: ", e)
# Out:
# Database 'Real_Estate' created successfully.

# %% [markdown]
# ## Creating Tables in Real_Estate Database

# %%
# Selecting the database
cur.execute("use Real_Estate")

# %%
#Creating agents table
create_table_query = """
    CREATE TABLE IF NOT EXISTS agents (
        Agent_ID VARCHAR(10),
        Email VARCHAR(100),
        Phone VARCHAR(20),
        Commission_Rate FLOAT,
        Deals_Closed INT,
        Rating FLOAT,
        Years_Of_Experience INT,
        Avg_Closing_Days INT
    )
    """

try:
    cur.execute(create_table_query)
    conn.commit()
    print("Agents Table Created Successfully.")
except mysql.connector.Error as e:
    print("Error: ", e)
# Out:
# Agents Table Created Successfully.

# %%
# Deleting if buyers table exists
cur.execute('drop table if exists buyers')

# Creating buyers table
create_table_query = """
  create table if not exists buyers (
    Buyer_ID int,
    Listing_ID varchar(30),
    Buyer_Type varchar(40),
    Payment_Method varchar(30),
    Loan_Taken bool,
    Loan_Provider varchar(30),
    Loan_Amount int 
  )
"""
try:
  cur.execute(create_table_query)
  conn.commit()
  print("Buyers Table Created Successfully.")
except mysql.connector.Error as e:
  print("Error: ", e)
# Out:
# Buyers Table Created Successfully.

# %%
# Deleting if listings table exists
cur.execute('drop table if exists listings')

# Creating listings table
create_table_query = """
  create table if not exists listings (
    Listing_ID varchar(30),
    City varchar(50),
    Property_Type varchar(30),
    Price decimal(20,2),
    Sqft decimal(20,2),
    Date_Listed date,
    Agent_ID VARCHAR(10),
    Latitude float,
    Longitude float
  )
"""

try:
  cur.execute(create_table_query)
  conn.commit()
  print("Listings Table Created Successfully.")

except mysql.connector.Error as e:
  print("Error: ", e)
# Out:
# Listings Table Created Successfully.

# %%
# Deleting if property_attributes table exists
cur.execute('drop table if exists property_attributes')

# Creating property_attributes table
create_table_query = """
  create table if not exists property_attributes (
    Attribute_ID int,
    Listing_ID varchar(30),
    Bedroom int,
    Bathroom int,
    Floor_Number int,
    Total_Floor int,
    Year_Built int,
    Is_Rented bool,
    Tenant_Count int,
    Furnishing_Status varchar(30),
    Metro_Distance float,
    Parking_Available bool,
    Power_Backup bool
  )
"""
try:
  cur.execute(create_table_query)
  conn.commit()
  print("Property Attributes Table Created Successfully.")

except mysql.connector.Error as e:
  print("Error: ", e)
# Out:
# Property Attributes Table Created Successfully.

# %%
# Deleting if sales table exists
cur.execute('drop table if exists sales')

# Creating sales table
create_table_query = """
  create table if not exists sales (
    Listing_ID varchar(30),
    Sale_Price float,
    Date_Sold date,
    Days_On_Market float
  )
"""

try:
  cur.execute(create_table_query)
  conn.commit()
  print("Sales Table Created Successfully.")

except mysql.connector.Error as e:
  print("Error: ", e)
# Out:
# Sales Table Created Successfully.

# %% [markdown]
# ## Inserting Values into Tables

# %%
# Inserting data into agents table
data_list = agents_df.values.tolist()
insert_query = """
  insert into agents (Agent_ID, Email, Phone, Commission_Rate, Deals_Closed, Rating, Years_Of_Experience, Avg_Closing_Days)
  values (%s, %s, %s, %s, %s, %s, %s, %s)
"""
try:
  cur.executemany(insert_query, data_list)
  conn.commit()
  print("Data inserted into agents table successfully. ")

except mysql.connector.Error as e:
  print('Error: ',e)
# Out:
# Data inserted into agents table successfully.

# %%
#  Inserting data into buyers table
data_list = buyers_df.values.tolist()
insert_query = """
  insert into buyers (Buyer_ID, Listing_ID, Buyer_Type, Payment_Method, Loan_Taken, Loan_Provider, Loan_Amount)
  values (%s, %s, %s, %s, %s, %s,%s)
"""
try:
  cur.executemany(insert_query, data_list)
  conn.commit()
  print("Data inserted into buyers table successfully. ")

except mysql.connector.Error as e:
  print('Error: ',e)
# Out:
# Data inserted into buyers table successfully.

# %%
# Inserting data into listings table
data_list = listings_df.values.tolist()
insert_query = """
  insert into listings (Listing_ID, City, Property_Type, Price, Sqft, Date_Listed, Agent_ID, Latitude, Longitude)
  values (%s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

try:
  cur.executemany(insert_query, data_list)
  conn.commit()
  print("Data inserted into listings table successfully. ")

except mysql.connector.Error as e:
  print('Error: ',e)
# Out:
# Data inserted into listings table successfully.

# %%
# Inserting data into property_attributes table
data_list = prop_att_df.values.tolist()
insert_query = """
  insert into property_attributes (Attribute_ID, Listing_ID, Bedroom, Bathroom, Floor_Number, Total_Floor, Year_Built, Is_Rented, Tenant_Count, Furnishing_Status, Metro_Distance, Parking_Available, Power_Backup)
  values (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

try:
  cur.executemany(insert_query, data_list)
  conn.commit()
  print("Data inserted into property_attributes table successfully. ")

except mysql.connector.Error as e:
  print('Error: ',e)
# Out:
# Data inserted into property_attributes table successfully.

# %%
# Inserting data into sales table
data_list = sales_df.values.tolist()
insert_query = """
  insert into sales (Listing_ID, Sale_Price, Date_Sold, Days_On_Market)
  values (%s, %s, %s, %s)
"""

try:
  cur.executemany(insert_query, data_list)
  conn.commit()
  print("Data inserted into sales table successfully. ")

except mysql.connector.Error as e:
  print('Error: ',e)
# Out:
# Data inserted into sales table successfully.

# %% [markdown]
# # Property & Pricing Analysis

# %% [markdown]
# ### Q1. What is the average listing price by city

# %%
# Calculating the avg listing price by city
query = """
  select
    City,
    round(avg(Price), 2) 
  from listings
  group by City
  order by City;
"""
cur.execute(query)
result_1 = cur.fetchall()

# Table Headers
headers_1 = ['City', 'Avg_Price']
print(tabulate(result_1, headers=headers_1, tablefmt='grid'))
# Out:
# +-------------+-------------+
# | City        |   Avg_Price |
# +=============+=============+
# | Chicago     | 2.43068e+06 |
# +-------------+-------------+
# | Houston     | 2.43681e+06 |
# +-------------+-------------+
# | Los Angeles | 2.44242e+06 |
# +-------------+-------------+
# | New York    | 2.49332e+06 |
# +-------------+-------------+
# | Phoenix     | 2.45996e+06 |
# +-------------+-------------+

# %%
# Visualization
df = pd.DataFrame(result_1, columns=headers_1)

plt.figure(figsize=(10, 6))
plt.bar(df['City'], df['Avg_Price'])
plt.gca().yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)

for index, value in zip(df['City'], df['Avg_Price']):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.ylim(float(df['Avg_Price'].min())*0.95, float(df['Avg_Price'].max())*1.05)
plt.xlabel('City')
plt.ylabel('Price ($)')
plt.title('Average Listing Price')
plt.show()

# %% [markdown]
# ### Q2. What is the average price per square foot by property type?

# %%
# Price Per Sqft. based on property type
query = """
  select
    Property_Type,
    round(avg(Price_Per_Sqft), 2) as Avg_Price_Per_Sqft
  from
    (select
      Property_Type,
      (price/sqft) as Price_Per_Sqft
    from listings) T
  group by
    Property_Type
  order by
    Avg_Price_Per_Sqft;
"""
cur.execute(query)
result_2 = cur.fetchall()

# Define Headers
headers_2 = ['Property_Type', 'Avg_Price_Per_Sqft']
print(tabulate(result_2, headers=headers_2, tablefmt='grid'))
# Out:
# +-----------------+----------------------+
# | Property_Type   |   Avg_Price_Per_Sqft |
# +=================+======================+
# | Condo           |               754.68 |
# +-----------------+----------------------+
# | Townhouse       |               789.75 |
# +-----------------+----------------------+
# | Apartment       |               792.2  |
# +-----------------+----------------------+
# | House           |               796.04 |
# +-----------------+----------------------+

# %%
# Visualization
df = pd.DataFrame(result_2,  columns=headers_2)
plt.bar(df['Property_Type'], df['Avg_Price_Per_Sqft'])
plt.ylim(float(df['Avg_Price_Per_Sqft'].min())*0.95, float(df['Avg_Price_Per_Sqft'].max())*1.05)
plt.gca().yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)
for index, value in zip(df['Property_Type'], df['Avg_Price_Per_Sqft']):
    plt.text(index, value, str(value), ha='center', va='bottom')
plt.xlabel('Property Type')
plt.ylabel('Price ($)')
plt.title('Average Price Per Square Feet Based on Property Type')
plt.show()

# %% [markdown]
# ### Q3.1. How does furnishing status impact property prices

# %%
# Based on furnishing status
query = """
    select 
        p.furnishing_status as Furnishing_Status,
        count(*) as Total_Properties,
        round(avg(l.price), 2) as Avg_Price,
        min(l.price) as Min_Price,
        max(l.price) as Max_Price
    from listings l
    left join property_attributes p
    on l.listing_ID = p.listing_id
    group by
        Furnishing_Status
    order by
        Avg_Price;
"""

cur.execute(query)
results_3_1 = cur.fetchall()

# Define Headers
headers_3_1 = ['Furnishing_Status', 'Total_Properties', 'Avg_Price', 'Min_Price', 'Max_Price']
print(tabulate(results_3_1, headers=headers_3_1, tablefmt='grid'))
# Out:
# +---------------------+--------------------+-------------+-------------+-------------+
# | Furnishing_Status   |   Total_Properties |   Avg_Price |   Min_Price |   Max_Price |
# +=====================+====================+=============+=============+=============+
# | Unfurnished         |               7210 | 2.43398e+06 |      100459 | 4.99897e+06 |
# +---------------------+--------------------+-------------+-------------+-------------+
# | Semi-Furnished      |               7013 | 2.46119e+06 |      100027 | 4.99986e+06 |
# +---------------------+--------------------+-------------+-------------+-------------+
# | Furnished           |               6977 | 2.46354e+06 |      100082 | 4.99759e+06 |
# +---------------------+--------------------+-------------+-------------+-------------+

# %%
#Visualization Plot
df = pd.DataFrame(results_3_1, columns=headers_3_1)
plt.bar(df['Furnishing_Status'], df['Avg_Price'])
plt.ylim(float(df['Avg_Price'].min())*0.95, float(df['Avg_Price'].max())*1.05)
plt.gca().yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)

for index, value in zip(df['Furnishing_Status'], df['Avg_Price']):
    plt.text(index, value, str(value), ha='center', va='bottom')
    
plt.xlabel('Furnishing Status')
plt.ylabel('Price')
plt.title('Average Property Price Based on Furnishing Status')
plt.show()

# %% [markdown]
# ### Q3.2 How does furnishing status impact the property prices based on the city

# %%
# Based on the furnishing status for each city
query = """
    select
        l.city as City,
        p.furnishing_status as Furnishing_Status,
        count(*) as Total_Properties,
        round(avg(l.price), 2) as Avg_Price,
        min(l.price) as Min_Price,
        max(l.price) as Max_Price
    from listings l
    left join property_attributes p
    on l.listing_ID = p.listing_id
    group by
        City,
        Furnishing_Status
    order by
        City,
        Avg_Price desc;
"""
cur.execute(query)
results_3_2 = cur.fetchall()

# Define Headers
headers_3_2 = ['City', 'Furnishing_Status', 'Total_Properties', 'Avg_Price', 'Min_Price', 'Max_Price']
print(tabulate(results_3_2, headers=headers_3_2, tablefmt='grid'))
# Out:
# +-------------+---------------------+--------------------+-------------+-------------+-------------+
# | City        | Furnishing_Status   |   Total_Properties |   Avg_Price |   Min_Price |   Max_Price |
# +=============+=====================+====================+=============+=============+=============+
# | Chicago     | Furnished           |               1334 | 2.46831e+06 |      100082 | 4.99759e+06 |
# +-------------+---------------------+--------------------+-------------+-------------+-------------+
# | Chicago     | Semi-Furnished      |               1496 | 2.44932e+06 |      106673 | 4.98946e+06 |
# +-------------+---------------------+--------------------+-------------+-------------+-------------+
# | Chicago     | Unfurnished         |               1463 | 2.3773e+06  |      101958 | 4.99711e+06 |
# +-------------+---------------------+--------------------+-------------+-------------+-------------+
# ...

# %%
# Visualization Plot
df = pd.DataFrame(results_3_2, columns=headers_3_2)
ax = sns.barplot(
    data=df,
    x='City',
    y='Avg_Price',
    hue='Furnishing_Status'
)
plt.gca().yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)
plt.ylim(float(df['Avg_Price'].min())*0.95, float(df['Avg_Price'].max())*1.05)

# Bar label
for container in ax.containers:
    ax.bar_label(
        container, 
        fmt='{:.0f}', 
        label_type='center', 
        rotation=90,
        color='white'
    )

plt.xlabel('City')
plt.ylabel('Price($)')
plt.title('City-wise Comparison of Average Property Prices by Furnishing Status')
plt.show()

# %% [markdown]
# ### Q4. Do properties closer to metro stations command higher prices?

# %%
# Price based on the distance from the nearest metro station, ordered based on the minimum property price
query = """
    SELECT
        CASE
            when p.metro_distance <= 2 then '0-2'
            when p.metro_distance <= 5 && p.metro_distance > 2 then '2-5'
            when p.metro_distance <= 10 && p.metro_distance > 5 then '5-10'
            when p.metro_distance <= 15 && p.metro_distance > 10 then '10-15'
            else '15+'
        END AS Metro_Distance_In_KM,
        
        COUNT(*) AS Total_Properties,
        min(l.price) as Min_Price,
        max(l.price) as Max_Price,
        ROUND(AVG(l.price), 2) AS Avg_Price
        
    FROM property_attributes p
    INNER JOIN listings l
        ON p.listing_id = l.listing_id

    GROUP BY 
        Metro_Distance_In_KM
    ORDER BY 
        case Metro_Distance_In_KM
            when '0-2' then 1
            when '2-5' then 2
            when '5-10' then 3
            when '10-15' then 4
            when '15+' then 5
        end;
"""
cur.execute(query)
result_4_1 = cur.fetchall()

# Define Headers
headers_4_1 = ['Metro_Distance_In_KM', 'Total_Properties', 'Min_Price', 'Max_Price', 'Avg_Price']
print(tabulate(result_4_1, headers=headers_4_1, tablefmt='grid'))
# Out:
# +------------------------+--------------------+-------------+-------------+-------------+
# | Metro_Distance_In_KM   |   Total_Properties |   Min_Price |   Max_Price |   Avg_Price |
# +========================+====================+=============+=============+=============+
# | 0-2                    |               2908 |      101180 | 4.99711e+06 | 2.37783e+06 |
# +------------------------+--------------------+-------------+-------------+-------------+
# | 2-5                    |               4416 |      103383 | 4.99587e+06 | 2.40482e+06 |
# +------------------------+--------------------+-------------+-------------+-------------+
# | 5-10                   |               7218 |      100082 | 4.99986e+06 | 2.44298e+06 |
# +------------------------+--------------------+-------------+-------------+-------------+
# | 10-15                  |               6658 |      100027 | 4.99946e+06 | 2.52773e+06 |
# ...

# %%
# Visualization
df = pd.DataFrame(result_4_1, columns=headers_4_1)
plt.bar(df['Metro_Distance_In_KM'], df['Avg_Price'])
plt.gca().yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)

for index, value in zip(df['Metro_Distance_In_KM'], df['Avg_Price']):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.ylim(float(df['Avg_Price'].min())*0.95, float(df['Avg_Price'].max())*1.05)
plt.xlabel('Distance (KM)')
plt.ylabel('Average Price($)')
plt.title('Metro Accessibility vs. Property Prices')
plt.show()

# %% [markdown]
# ### Q5. Are rented properties priced differently from non-rented ones?

# %%
# Comparing the prices of properties which are rented and not rented, ordered by minimum price
query = """
    select 

        case
            when is_rented is True then 'Yes'
            else 'No'
        end as Property_Rented,
        count(*) as Total_Properties,
        min(l.Price) as Min_Price,
        max(l.Price) as Max_Price,
        round(avg(l.Price), 2) as Avg_Price
        
    FROM property_attributes p
    INNER JOIN listings l
        ON p.listing_id = l.listing_id
        
    group by
        Property_Rented;
"""

cur.execute(query)
result_5_1 = cur.fetchall()

# Define Headers
headers_5_1 = ['Property_Rented', 'Total_Properties', 'Min_Price', 'Max_Price', 'Avg_Price']
print(tabulate(result_5_1, headers=headers_5_1, tablefmt='grid'))
# Out:
# +-------------------+--------------------+-------------+-------------+-------------+
# | Property_Rented   |   Total_Properties |   Min_Price |   Max_Price |   Avg_Price |
# +===================+====================+=============+=============+=============+
# | Yes               |              10578 |      100082 | 4.99986e+06 | 2.45718e+06 |
# +-------------------+--------------------+-------------+-------------+-------------+
# | No                |              10622 |      100027 | 4.99946e+06 | 2.44825e+06 |
# +-------------------+--------------------+-------------+-------------+-------------+

# %%
# Comparing the price based on the furnishing Status, ordered by Avg_Price
query = """
  select 

    case
      when is_rented is True then 'Yes'
      else 'No'
    end as Property_Rented,
      p.Furnishing_Status as Furnishing_Status,
      count(*) as Total_Properties,
      min(l.Price) as Min_Price,
      max(l.Price) as Max_Price,
      round(avg(l.Price), 2) as Avg_Price
      
  FROM property_attributes p
  INNER JOIN listings l
      ON p.listing_id = l.listing_id
      
  group by
    Furnishing_Status,
    Property_Rented
  order by
	  Property_Rented,
    Furnishing_Status desc;

"""
cur.execute(query)
result_5_2 = cur.fetchall()

# Define Headers
headers_5_2 = ['Property_Rented', 'Furnishing_Status', 'Total_Properties', 'Min_Price', 'Max_Price', 'Avg_Price']
print(tabulate(result_5_2, headers=headers_5_2, tablefmt='grid'))
# Out:
# +-------------------+---------------------+--------------------+-------------+-------------+-------------+
# | Property_Rented   | Furnishing_Status   |   Total_Properties |   Min_Price |   Max_Price |   Avg_Price |
# +===================+=====================+====================+=============+=============+=============+
# | No                | Unfurnished         |               3644 |      100459 | 4.99642e+06 | 2.42892e+06 |
# +-------------------+---------------------+--------------------+-------------+-------------+-------------+
# | No                | Semi-Furnished      |               3463 |      100027 | 4.99946e+06 | 2.45276e+06 |
# +-------------------+---------------------+--------------------+-------------+-------------+-------------+
# | No                | Furnished           |               3515 |      100882 | 4.99628e+06 | 2.46384e+06 |
# +-------------------+---------------------+--------------------+-------------+-------------+-------------+
# ...

# %%
# Visualization
df = pd.DataFrame(result_5_2, columns=headers_5_2)
ax = sns.barplot(
    data=df,
    x='Property_Rented',
    y='Avg_Price',
    hue='Furnishing_Status'
)
plt.gca().yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)

for container in ax.containers:
    ax.bar_label(
        container, 
        fmt='{:.0f}', 
        label_type='center', 
        rotation=90,
        color='white'
    )

plt.ylim(float(df['Avg_Price'].min())*0.95, float(df['Avg_Price'].max())*1.05)
plt.xlabel('Rent Status')
plt.ylabel('Price($)')
plt.title('City-wise Comparison of Average Property Prices by Furnishing Statusy')
plt.show()

# %% [markdown]
# ### Q6. How do bedrooms and bathrooms affect pricing?

# %%
# Only Bedroom
query = """
  select 

    p.Bedroom as Bedroom_Count,
      count(*) as Total_Properties,
      min(l.price) as Min_Price,
      max(l.price) as Max_Price,
      round(avg(l.price), 2) as Avg_Price
      
  FROM property_attributes p
  INNER JOIN listings l
      ON p.listing_id = l.listing_id
      
  group by
    Bedroom_Count
  order by
    bedroom_count;
"""

cur.execute(query)
result_6_1 = cur.fetchall()

# Define Headers
headers_6_1 = ['Bedroom_Count', 'Total_Properties', 'Min_Price', 'Max_Price', 'Avg_Price']
print(tabulate(result_6_1, headers=headers_6_1, tablefmt='grid'))
# Out:
# +-----------------+--------------------+-------------+-------------+-------------+
# |   Bedroom_Count |   Total_Properties |   Min_Price |   Max_Price |   Avg_Price |
# +=================+====================+=============+=============+=============+
# |               1 |               4209 |      100613 | 4.99946e+06 | 2.46449e+06 |
# +-----------------+--------------------+-------------+-------------+-------------+
# |               2 |               4276 |      103066 | 4.99897e+06 | 2.46598e+06 |
# +-----------------+--------------------+-------------+-------------+-------------+
# |               3 |               4194 |      100331 | 4.99986e+06 | 2.44231e+06 |
# +-----------------+--------------------+-------------+-------------+-------------+
# |               4 |               4269 |      100082 | 4.99759e+06 | 2.43834e+06 |
# +-----------------+--------------------+-------------+-------------+-------------+
# ...

# %%
# Visualization Plot
df = pd.DataFrame(result_6_1, columns=headers_6_1)

plt.bar(df['Bedroom_Count'], df['Avg_Price'])
plt.gca().yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)

for index, value in zip(df['Bedroom_Count'], df['Avg_Price']):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.ylim(float(min(df['Avg_Price']))*0.95, float(max(df['Avg_Price']))*1.05)
plt.xlabel('Number of Bedrooms')
plt.ylabel('Price ($)')
plt.title('Average Property Price Based on Number of Bedrooms')
plt.show()

# %%
# Only Bathroom
query = """
  select 

    p.bathroom as Bathroom_Count,
    count(*) as Total_Properties,
    min(l.price) as Min_Price,
    max(l.price) as Max_Price,
    round(avg(l.price), 2) as Avg_Price
      
  FROM property_attributes p
  INNER JOIN listings l
    ON p.listing_id = l.listing_id

  group by
    Bathroom_Count
  order by
    Bathroom_Count;
"""
cur.execute(query)
result_6_2 = cur.fetchall()

headers_6_2 = ['Bathroom_Count', 'Total_Properties', 'Min_Price', 'Max_Price', 'Avg_Price']
print(tabulate(result_6_2, headers=headers_6_2, tablefmt='grid'))
# Out:
# +------------------+--------------------+-------------+-------------+-------------+
# |   Bathroom_Count |   Total_Properties |   Min_Price |   Max_Price |   Avg_Price |
# +==================+====================+=============+=============+=============+
# |                1 |               5315 |      100459 | 4.99402e+06 | 2.4269e+06  |
# +------------------+--------------------+-------------+-------------+-------------+
# |                2 |               5341 |      101202 | 4.99946e+06 | 2.44422e+06 |
# +------------------+--------------------+-------------+-------------+-------------+
# |                3 |               5218 |      100027 | 4.99986e+06 | 2.44291e+06 |
# +------------------+--------------------+-------------+-------------+-------------+
# |                4 |               5326 |      100331 | 4.99897e+06 | 2.49658e+06 |
# +------------------+--------------------+-------------+-------------+-------------+

# %%
# Visualization Plot
df = pd.DataFrame(result_6_2, columns=headers_6_2)

plt.bar(df['Bathroom_Count'], df['Avg_Price'])
plt.gca().yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)

for index, value in zip(df['Bathroom_Count'], df['Avg_Price']):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.ylim(float(min(df['Avg_Price']))*0.95, float(max(df['Avg_Price']))*1.05)
plt.xticks(np.arange(1, 5, 1))
plt.xlabel('Number of Bathrooms')
plt.ylabel('Price ($)')
plt.title('Average Property Price Based on Number of Bathrooms')
plt.show()

# %%
# Both Bedroom and Bathroom together
query = """
    select

        p.bedroom as Bedroom_Count,
        p.bathroom as Bathroom_Count,
        count(*) as Total_Properties,
        min(l.price) as Min_Price,
        max(l.price) as Max_Price,
        round(avg(l.price), 2) as Avg_Price

    FROM property_attributes p
    INNER JOIN listings l
        ON p.listing_id = l.listing_id
        
    group by
        bedroom,
        bathroom
    order by
        Bedroom_Count,
        Bathroom_Count;
"""

cur.execute(query)
result_6_3 = cur.fetchall()

# Define headers
headers_6_3 = ['Bedroom_Count', 'Bathroom_Count', 'Total_Properties', 'Min_Price', 'Max_Price', 'Avg_Price']
print(tabulate(result_6_3, headers=headers_6_3, tablefmt='grid'))
# Out:
# +-----------------+------------------+--------------------+-------------+-------------+-------------+
# |   Bedroom_Count |   Bathroom_Count |   Total_Properties |   Min_Price |   Max_Price |   Avg_Price |
# +=================+==================+====================+=============+=============+=============+
# |               1 |                1 |               1040 |      102914 | 4.99162e+06 | 2.434e+06   |
# +-----------------+------------------+--------------------+-------------+-------------+-------------+
# |               1 |                2 |               1047 |      106350 | 4.99946e+06 | 2.50947e+06 |
# +-----------------+------------------+--------------------+-------------+-------------+-------------+
# |               1 |                3 |               1028 |      100613 | 4.99252e+06 | 2.45903e+06 |
# +-----------------+------------------+--------------------+-------------+-------------+-------------+
# ...

# %%
# Visualization
df = pd.DataFrame(result_6_3, columns=headers_6_3)
df['Avg_Price'] = pd.to_numeric(df['Avg_Price'], errors='coerce')

# Pivot the dataframe
pivot_df = df.pivot(index='Bedroom_Count',
                    columns='Bathroom_Count',
                    values='Avg_Price')

#plt.figure(figsize=(12,8))
ax = sns.heatmap(pivot_df,
            annot=True,
            fmt=",.0f",
            cmap="YlGnBu")

# Format colorbar
cbar = ax.collections[0].colorbar
cbar.ax.yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)

plt.title("Average Price by Bedroom and Bathroom")
plt.ylabel("Bedroom")
plt.xlabel("Bathroom")
plt.show()

# %% [markdown]
# ### Q7. Do properties with parking and power backup sell at higher prices?

# %%
# How properties are priced based on the availability of parking space and power backup
query = """
  select

    case
        when p.parking_available is True then 'Yes'
        else 'No'
      end as Parking_Available,
    case
      when p.power_backup is True then 'Yes'
          else 'No'
    end as Power_Backup_Available,
    count(*) as Total_Properties,
    round(avg(l.price), 2) as Avg_Price,
    min(l.price) as Min_Price,
    max(l.price) as Max_Price
    
  FROM property_attributes p
  INNER JOIN listings l
    ON p.listing_id = l.listing_id
      
  group by
    Parking_Available,
    Power_Backup_Available
  order by
    Parking_Available,
    Power_Backup_Available;
"""

cur.execute(query)
result_7 = cur.fetchall()

# Define Headers
headers_7 = ['Parking_Available', 'Power_Backup_Available', 'Total_Properties', 'Avg_Price', 'Min_Price', 'Max_Price']
print(tabulate(result_7, headers=headers_7, tablefmt='grid'))
# Out:
# +---------------------+--------------------------+--------------------+-------------+-------------+-------------+
# | Parking_Available   | Power_Backup_Available   |   Total_Properties |   Avg_Price |   Min_Price |   Max_Price |
# +=====================+==========================+====================+=============+=============+=============+
# | No                  | No                       |               5408 | 2.43668e+06 |      100331 | 4.99711e+06 |
# +---------------------+--------------------------+--------------------+-------------+-------------+-------------+
# | No                  | Yes                      |               5166 | 2.44629e+06 |      100027 | 4.99986e+06 |
# +---------------------+--------------------------+--------------------+-------------+-------------+-------------+
# | Yes                 | No                       |               5383 | 2.46236e+06 |      100459 | 4.99946e+06 |
# ...

# %%
# Visualization
df = pd.DataFrame(result_7, columns=headers_7)
df['Avg_Price'] = df['Avg_Price'].astype(float)

# Pivot Table
pivot_df = df.pivot(
    index='Parking_Available',
    columns='Power_Backup_Available',
    values='Avg_Price'
)

ax = sns.heatmap(
    data=pivot_df,
    annot=True,
    fmt=',.0f',
    cmap='YlGnBu'
)

# Format colorbar
cbar = ax.collections[0].colorbar
cbar.ax.yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)

plt.title("Price by Parking and Power Backup")
plt.ylabel("Parking")
plt.xlabel("Power Backup")
plt.show()

# %% [markdown]
# ### Q8. How does year built influence listing price?

# %%
# Property Pring over the years (1990 - 2023)
query = """
  select

    p.Year_Built as Year_Built,
    count(*) as Total_Properties,
    round(avg(l.Price), 2) as Avg_Price,
    min(l.Price) as Min_Price,
    max(l.Price) as Max_Price
      
  FROM property_attributes p
  INNER JOIN listings l
    ON p.listing_id = l.listing_id
      
  group by
    Year_Built
  order by
    Year_Built;
"""
cur.execute(query)
result_8 = cur.fetchall()

# Define Headers
headers_8 = ['Year_Built', 'Total_Properties', 'Avg_Price', 'Min_Price', 'Max_Price']
print(tabulate(result_8, headers=headers_8, tablefmt='grid'))
# Out:
# +--------------+--------------------+-------------+-------------+-------------+
# |   Year_Built |   Total_Properties |   Avg_Price |   Min_Price |   Max_Price |
# +==============+====================+=============+=============+=============+
# |         1990 |                607 | 2.53379e+06 |      101202 | 4.98687e+06 |
# +--------------+--------------------+-------------+-------------+-------------+
# |         1991 |                605 | 2.57392e+06 |      102914 | 4.96531e+06 |
# +--------------+--------------------+-------------+-------------+-------------+
# |         1992 |                574 | 2.59465e+06 |      105033 | 4.9881e+06  |
# +--------------+--------------------+-------------+-------------+-------------+
# |         1993 |                548 | 2.61175e+06 |      100459 | 4.99946e+06 |
# +--------------+--------------------+-------------+-------------+-------------+
# |         1994 |                608 | 2.5715e+06  |      106126 | 4.99897e+06 |
# ...

# %%
# Creating a Visual Plot
df = pd.DataFrame(result_8, columns=['Year_Built', 'Total_Properties', 'Avg_Price', 'Min_Price', 'Max_Price'])

plt.figure(figsize=(12, 6))
plt.plot(df['Year_Built'], df['Avg_Price'], marker='o')
plt.xticks(range(1990, 2023, 5))
plt.gca().yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)
plt.xlabel('Year')
plt.ylabel('Avg Price($)')

plt.title("Yearly Average Property Price Trend (1990-2023)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Q9. Which City have the highest Median Property Price?

# %%
# Cities and their median property prices
query = """
    select
        City,
        round(avg(Price), 2) as Median_Price
    from
        (select
            City,
            Price,
            row_number() over (
                partition by city
                order by price
            ) as Row_Num,
            count(*) over (
                partition by city
            ) as Total_Count
        from listings) T
    where row_num in (
        Floor((Total_Count + 1) / 2),
        Floor((Total_Count + 2) / 2)
    )
    group by
        City
    order by
        City;
"""
cur.execute(query)
result_9 = cur.fetchall()

# Define headers
headers_9 = ['City', 'Median_Price']
print(tabulate(result_9, headers=headers_9, tablefmt='grid'))
# Out:
# +-------------+----------------+
# | City        |   Median_Price |
# +=============+================+
# | Chicago     |    2.35108e+06 |
# +-------------+----------------+
# | Houston     |    2.34758e+06 |
# +-------------+----------------+
# | Los Angeles |    2.38093e+06 |
# +-------------+----------------+
# | New York    |    2.44652e+06 |
# +-------------+----------------+
# | Phoenix     |    2.3976e+06  |
# +-------------+----------------+

# %%
# Creating a Visualization Plot
df = pd.DataFrame(result_9, columns=['City', 'Median_Price'])
#plt.plot(df['City'], df['Median_Price'], marker='o')
plt.bar(df['City'], df['Median_Price'])
plt.gca().yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)

for index, value in zip(df['City'], df['Median_Price']):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.ylim(float(df['Median_Price'].min())*0.95, float(df['Median_Price'].max())*1.05)
plt.xlabel('City')
plt.ylabel('Median Price($)')
plt.title('Median Property Price Based On City')
plt.show()

# %% [markdown]
# ### Q10. How are properties distributed across price buckets?

# %%
# Property Disctibution Across Different Price Range (100k to 5M)
query = """
select 
    T3.Price_Bucket,
    T3.Total_Properties,
    T3.Avg_Price,
    T3.Min_Price,
    T3.Max_Price,
    T2.Top_Property_Type as Top_Property_Type,
    T2.Property_Count as Top_Property_Count
    
from

	(select
			Price_Bucket,
			Property_Type as Top_Property_Type,
			Property_Count

	from

		(select
			CASE
				WHEN price >= 100000 AND price < 500000 THEN '100K - 500K'
				WHEN price >= 500000 AND price < 1000000 THEN '500K - 1M'
				WHEN price >= 1000000 AND price < 2000000 THEN '1M - 2 M'
				WHEN price >= 2000000 AND price < 3000000 THEN '2M - 3M'
				WHEN price >= 3000000 AND price < 4000000 THEN '3M - 4M'
				WHEN price >= 4000000 AND price < 5000000 THEN '4M - 5M'
			END AS Price_Bucket,
            property_type,
            count(*) as Property_Count,
            row_number() over(
            partition by
                CASE
                    WHEN price >= 100000 AND price < 500000 THEN '100K - 500K'
                    WHEN price >= 500000 AND price < 1000000 THEN '500K - 1M'
                    WHEN price >= 1000000 AND price < 2000000 THEN '1M - 2 M'
                    WHEN price >= 2000000 AND price < 3000000 THEN '2M - 3M'
                    WHEN price >= 3000000 AND price < 4000000 THEN '3M - 4M'
                    WHEN price >= 4000000 AND price < 5000000 THEN '4M - 5M'
                END 
                order by count(*) desc
			) as Row_Num

		from listings
		group by
			Price_Bucket,
			Property_Type) T1
	where Row_Num = 1) T2

	inner join

    (
    SELECT

        CASE
            WHEN price >= 100000 AND price < 500000 THEN '100K - 500K'
            WHEN price >= 500000 AND price < 1000000 THEN '500K - 1M'
            WHEN price >= 1000000 AND price < 2000000 THEN '1M - 2 M'
            WHEN price >= 2000000 AND price < 3000000 THEN '2M - 3M'
            WHEN price >= 3000000 AND price < 4000000 THEN '3M - 4M'
            WHEN price >= 4000000 AND price < 5000000 THEN '4M - 5M'
        END AS Price_Bucket,
        count(*) as Total_Properties,
        round(avg(price), 2) as Avg_Price,
        MIN(price) AS Min_Price,
        MAX(price) AS Max_Price
        
    FROM listings
    GROUP BY Price_Bucket
    ORDER BY
        CASE Price_Bucket
            WHEN '100K - 500K' THEN 1
            WHEN '500K - 1M' THEN 2
            WHEN '1M - 2 M' THEN 3
            WHEN '2M - 3M' THEN 4
            WHEN '3M - 4M' THEN 5
            WHEN '4M - 5M' THEN 6
        END
    ) T3
on T2.Price_Bucket = T3.Price_Bucket
order by
CASE T3.Price_Bucket
	WHEN '100K - 500K' THEN 1
	WHEN '500K - 1M' THEN 2
	WHEN '1M - 2 M' THEN 3
	WHEN '2M - 3M' THEN 4
	WHEN '3M - 4M' THEN 5
	WHEN '4M - 5M' THEN 6
END;
"""

cur.execute(query)
result = cur.fetchall()

# Define Headers
headers = ['Price_Bucket', 'Total_Properties', 'Avg_Price', 'Min_Price', 'Max_Price', 'Top_Property_Type', 'Top_Property_Count']
print(tabulate(result, headers=headers, tablefmt='grid'))
# Out:
# +----------------+--------------------+------------------+------------------+------------------+---------------------+----------------------+
# | Price_Bucket   |   Total_Properties |        Avg_Price |        Min_Price |        Max_Price | Top_Property_Type   |   Top_Property_Count |
# +================+====================+==================+==================+==================+=====================+======================+
# | 100K - 500K    |               1867 | 302821           | 100027           | 499478           | Apartment           |                  485 |
# +----------------+--------------------+------------------+------------------+------------------+---------------------+----------------------+
# | 500K - 1M      |               2402 | 748047           | 500242           | 999596           | Condo               |                  638 |
# ...

# %%
# Creating Visualization Chart
df = pd.DataFrame(result, columns=['Price_Range', 'Total_Properties', 'Avg_Price', 'Min_Price', 'Max_Price', 'Top_Property_Type', 'Top_Property_Count'])

plt.figure(figsize=(10,4))
plt.bar(df['Price_Range'], df['Total_Properties'], label=df['Total_Properties'])

for index, value in zip(df['Price_Range'], df['Total_Properties']):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.ylim(0, 5500)
plt.xlabel('Price Range($)')
plt.ylabel("No. of Properties")
plt.title('Property Distribution Across Different Price Range')
plt.show()

# %% [markdown]
# # Sales and Market Performance Analysis

# %% [markdown]
# ### Q11. What is the average days on market by city?

# %%
# avg days in market
query = """
    select
        l.City,
        round(avg(s.Days_On_Market), 0) as Avg_Days_On_Market
    from sales s
    inner join listings l
    on s.Listing_ID = l.Listing_ID
    group by
        l.City
    order by
        City;
"""
cur.execute(query)
result_11 = cur.fetchall()

# Define Headers
headers = ['City', 'Avg_Days_On_Market']
print(tabulate(result_11, headers=headers, tablefmt='grid'))
# Out:
# +-------------+----------------------+
# | City        |   Avg_Days_On_Market |
# +=============+======================+
# | Chicago     |                   64 |
# +-------------+----------------------+
# | Houston     |                   59 |
# +-------------+----------------------+
# | Los Angeles |                   65 |
# +-------------+----------------------+
# | New York    |                   61 |
# +-------------+----------------------+
# | Phoenix     |                   60 |
# +-------------+----------------------+

# %%
# Visualization
df = pd.DataFrame(result_11, columns=headers)
df['Avg_Days_On_Market'] = df['Avg_Days_On_Market'].astype(int)
plt.bar(df['City'], df['Avg_Days_On_Market'])
plt.gca().yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)

for index, value in zip(df['City'], df['Avg_Days_On_Market']):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.ylim(0, 100)

plt.xlabel('City')
plt.ylabel('Days')
plt.title('Average Days On Market by City')
plt.show()

# %% [markdown]
# ### Q12. Which property types sell the fastest?

# %%
# Fastest selling property

query = """
    select
        l.Property_Type,
        round(avg(s.Days_On_Market), 0) as Avg_Days_On_Sale,
        min(s.Days_On_Market) as Min_Days_On_Market,
        max(s.Days_On_Market) as Max_Days_On_Market
    from sales s
    inner join listings l
    on s.Listing_ID = l.Listing_ID
    group by
        l.Property_Type
    order by
        Avg_Days_On_Sale;
"""

cur.execute(query)
result_12 = cur.fetchall()

# Define Headers
headers_12 = ['Property_Type', 'Avg_Days_On_Sale', 'Min_Days_On_Market', 'Max_Days_On_Market']
print(tabulate(result_12, headers=headers_12, tablefmt='grid'))
# Out:
# +-----------------+--------------------+----------------------+----------------------+
# | Property_Type   |   Avg_Days_On_Sale |   Min_Days_On_Market |   Max_Days_On_Market |
# +=================+====================+======================+======================+
# | House           |                 58 |                    5 |                  119 |
# +-----------------+--------------------+----------------------+----------------------+
# | Apartment       |                 61 |                    5 |                  120 |
# +-----------------+--------------------+----------------------+----------------------+
# | Townhouse       |                 61 |                    5 |                  120 |
# +-----------------+--------------------+----------------------+----------------------+
# | Condo           |                 67 |                    5 |                  120 |
# +-----------------+--------------------+----------------------+----------------------+

# %%
# Visualization
df = pd.DataFrame(result_12, columns=headers_12)
df['Avg_Days_On_Sale'] = df['Avg_Days_On_Sale'].astype(int)

plt.bar(df['Property_Type'], df['Avg_Days_On_Sale'])
for index, value in zip(df['Property_Type'], df['Avg_Days_On_Sale']):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.ylim(0,100)
plt.xlabel('Property Type')
plt.ylabel('Days')
plt.title('Average Days Taken For a Property To Be Sold')
plt.show()

# %% [markdown]
# ### Q13. What percentage of properties are sold above listing price?

# %%
# Percentage of properties sold above listing price
query = """
    select
        case 
            when s.Sale_Price > l.Price then 'Above Listed Price'
            when s.Sale_Price <= l.Price then 'Equal and Below Listed Price'
        end as Property_Sold_At,
        count(*) as Property_Count,
        round(( 100 * count(*)) / (select count(*) as Total_Properties
            from sales s
            inner join listings l
            on s.Listing_ID = l.Listing_ID), 2) Percentage_Sold
    from sales s
    inner join listings l
    on s.Listing_ID = l.Listing_ID
    group by
        Property_Sold_At;
"""
cur.execute(query)
result_13 = cur.fetchall()

# Define Headers
headers_13 = ['Property_Sold_At', 'Property_Count', 'Percentage_Sold']
print(tabulate(result_13, headers=headers_13, tablefmt='grid'))
# Out:
# +------------------------------+------------------+-------------------+
# | Property_Sold_At             |   Property_Count |   Percentage_Sold |
# +==============================+==================+===================+
# | Above Listed Price           |              355 |             49.31 |
# +------------------------------+------------------+-------------------+
# | Equal and Below Listed Price |              365 |             50.69 |
# +------------------------------+------------------+-------------------+

# %%
# Visualization
df = pd.DataFrame(result_13, columns=headers_13)
fig, ax = plt.subplots()
ax.pie(df['Percentage_Sold'], labels=df['Property_Sold_At'], autopct='%.2f%%')
plt.title('Distribution of Sales Relative to Listing Price')
plt.show()

# %% [markdown]
# ### Q14. What is the sale-to-list price ratio by city?

# %%
# Sale to list price ratio
query = """
    select
        city,
        round(avg(ratio), 4) as Sale_To_List_Price_Ratio
    from
    (select 
        City,
        l.Price,
        s.Sale_Price,
        (s.Sale_Price/l.Price) as ratio
    from 
        sales s
    inner join listings l
    on s.Listing_ID = l.Listing_ID) T
    group by
        city;
"""
cur.execute(query)
result_14 = cur.fetchall()

# Define Headers
headers_14 = ['City', 'Avg_Sale_To_List_Price_Ratio']
print(tabulate(result_14, headers=headers_14, tablefmt='grid'))
# Out:
# +-------------+--------------------------------+
# | City        |   Avg_Sale_To_List_Price_Ratio |
# +=============+================================+
# | New York    |                         0.9996 |
# +-------------+--------------------------------+
# | Houston     |                         1      |
# +-------------+--------------------------------+
# | Phoenix     |                         0.9989 |
# +-------------+--------------------------------+
# | Los Angeles |                         0.9998 |
# +-------------+--------------------------------+
# | Chicago     |                         1.0015 |
# +-------------+--------------------------------+

# %% [markdown]
# ### Q15. Which listings took more than 90 days to sell?

# %%
# Properties that took more than 90 days to sell

query = """
    select 
        s.Listing_ID,
        s.Days_On_Market,
        s.Date_Sold,
        l.Date_Listed,
        s.Sale_Price,
        l.Price as Listed_Price,
        l.City,
        l.Property_Type
    from sales s
    inner join listings l
    on s.Listing_ID = l.Listing_ID
    where s.Days_On_Market > 90
    order by
        Listing_ID;
"""
cur.execute(query)
result_15 = cur.fetchall()

# Define Headers
headers_15 = ['Listing_ID', 'Days_On_Market', 'Date_Sold', 'Date_Listed', 'Sale_Price', 'Listed_Price', 'City', 'Property_Type']
print(tabulate(result_15, headers=headers_15, tablefmt='grid'))
# Out:
# +--------------+------------------+-------------+---------------+------------------+------------------+-------------+-----------------+
# | Listing_ID   |   Days_On_Market | Date_Sold   | Date_Listed   |       Sale_Price |     Listed_Price | City        | Property_Type   |
# +==============+==================+=============+===============+==================+==================+=============+=================+
# | L00004       |              116 | 2024-04-27  | 2024-01-02    |      1.21504e+06 |      1.27702e+06 | Phoenix     | Apartment       |
# +--------------+------------------+-------------+---------------+------------------+------------------+-------------+-----------------+
# | L00007       |              108 | 2023-06-10  | 2023-02-22    |      1.62594e+06 |      1.70116e+06 | Los Angeles | House           |
# +--------------+------------------+-------------+---------------+------------------+------------------+-------------+-----------------+
# ...

# %% [markdown]
# ### Q16. How does metro distance affect time on market?

# %%
# Average days taken to sell a property, based on metro distance
query ="""
    select
        case
            when p.metro_distance < 2 then '0-2'
            when p.metro_distance < 5 && p.metro_distance >= 2 then '2-5'
            when p.metro_distance < 10 && p.metro_distance >= 5 then '5-10'
            when p.metro_distance < 15 && p.metro_distance >= 10 then '10-15'
            when p.metro_distance >= 15 then '15+'
        end as Metro_Distance_In_KM,
        round(avg(s.Days_on_Market), 0) as Avg_Days_On_Market,
        min(s.Days_On_Market) as Min_Days_On_Market,
        max(s.Days_On_Market) as Max_Days_On_Market
    from
        sales s
        inner join property_attributes p
        on s.listing_id=p.listing_id
    group by
        Metro_Distance_In_KM
    order by
        case Metro_Distance_In_KM
            when '0-2' then 1
            when '2-5' then 2
            when '5-10' then 3
            when '10-15' then 4
            when '15+' then 5
        end;
"""
cur.execute(query)
result_16 = cur.fetchall()

# Define Headers  
headers_16 = ['Metro_Distance_In_KM', 'Avg_Days_On_Market', 'Min_Days_On_Market', 'Max_Days_On_Market']
print(tabulate(result_16, headers=headers_16, tablefmt='grid'))
# Out:
# +------------------------+----------------------+----------------------+----------------------+
# | Metro_Distance_In_KM   |   Avg_Days_On_Market |   Min_Days_On_Market |   Max_Days_On_Market |
# +========================+======================+======================+======================+
# | 0-2                    |                   65 |                    5 |                  119 |
# +------------------------+----------------------+----------------------+----------------------+
# | 2-5                    |                   61 |                    5 |                  120 |
# +------------------------+----------------------+----------------------+----------------------+
# | 5-10                   |                   61 |                    5 |                  120 |
# +------------------------+----------------------+----------------------+----------------------+

# %%
# Visualization
df = pd.DataFrame(result_16, columns=headers_16)
df['Avg_Days_On_Market'] = df['Avg_Days_On_Market'].astype(int)

plt.bar(df['Metro_Distance_In_KM'], df['Avg_Days_On_Market'])
for index, value in zip(df['Metro_Distance_In_KM'], df['Avg_Days_On_Market']):
    plt.text(index, value, str(value), va='bottom', ha='center')

plt.ylim(0,100)
plt.xlabel('Metro Distance (KM)')
plt.ylabel('Days')
plt.title("Average Days On Market Based on Metro Distance")
plt.show()

# %% [markdown]
# ### Q17. What is the monthly sales trend?

# %%
# Monthly sales trend
query = """
    select
	case
		when Month(Date_Sold) = 1 then 'Jan'
		when Month(Date_Sold) = 2 then 'Feb'
		when Month(Date_Sold) = 3 then 'Mar'
		when Month(Date_Sold) = 4 then 'Apr'
		when Month(Date_Sold) = 5 then 'May'
		when Month(Date_Sold) = 6 then 'Jun'
		when Month(Date_Sold) = 7 then 'Jul'
		when Month(Date_Sold) = 8 then 'Aug'
		when Month(Date_Sold) = 9 then 'Sep'
		when Month(Date_Sold) = 10 then 'Oct'
		when Month(Date_Sold) = 11 then 'Nov'
		when Month(Date_Sold) = 12 then 'Dec'
	end as Month_Sold,
	Year(Date_Sold) as Year_Sold,
    count(*) as Total_Properties_Sold,
    round(sum(Sale_Price), 2) as Total_Sale_Amount,
	round(avg(Sale_Price), 2) as Avg_Sale_Price,
    min(Sale_Price) as Min_Sale_Price,
    max(Sale_Price) as Max_Sale_Price
from sales
group by
	Month_Sold,
    Year_Sold
order by
	year_Sold,
	case Month_Sold
		when 'Jan' then 1
		when 'Feb' then 2
		when 'Mar' then 3
		when 'Apr' then 4
		when 'May' then 5
		when 'Jun' then 6
		when 'Jul' then 7
		when 'Aug' then 8
		when 'Sep' then 9
		when 'Oct' then 10
		when 'Nov' then 11
		when 'Dec' then 12
	end; 
"""
cur.execute(query)
result_17 = cur.fetchall()

# Define headers
headers_17 = ['Month_Sold', 'Year_Sold', 'Total_Properties_Sold', 'Total_Sale_Amount', 'Avg_Sale_Price', 'Min_Sale_Price', 'Max_Sale_Price']
print(tabulate(result_17, headers=headers_17, tablefmt='grid'))
# Out:
# +--------------+-------------+-------------------------+---------------------+------------------+------------------+------------------+
# | Month_Sold   |   Year_Sold |   Total_Properties_Sold |   Total_Sale_Amount |   Avg_Sale_Price |   Min_Sale_Price |   Max_Sale_Price |
# +==============+=============+=========================+=====================+==================+==================+==================+
# | Jan          |        2023 |                       7 |         5.2984e+06  | 756914           |           444829 |      1.56292e+06 |
# +--------------+-------------+-------------------------+---------------------+------------------+------------------+------------------+
# | Feb          |        2023 |                      17 |         1.59451e+07 | 937945           |           163846 |      1.74034e+06 |
# +--------------+-------------+-------------------------+---------------------+------------------+------------------+------------------+
# ...

# %%
# Total Sales Visualization
df = pd.DataFrame(result_17, columns=headers_17)    
df['Month_Year'] = df['Month_Sold'] + '\n' + df['Year_Sold'].astype(str)

plt.figure(figsize=(16, 8))
plt.plot(df['Month_Year'], df['Total_Sale_Amount'], marker='o')
plt.gca().yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)
plt.xlabel('Month and Year')
plt.ylabel('Price ($)')
plt.title('Total Sales (2023-2024)')
plt.grid(True)

# %%
# Pricing Trend Visualization
df = pd.DataFrame(result_17, columns=headers_17)    
df['Month_Year'] = df['Month_Sold'] + '\n' + df['Year_Sold'].astype(str)

plt.figure(figsize=(16, 8))
plt.plot(df['Month_Year'], df['Avg_Sale_Price'], marker='o', label='Average Price')
plt.plot(df['Month_Year'], df['Min_Sale_Price'], marker='o', label='Minimum Price')
plt.plot(df['Month_Year'], df['Max_Sale_Price'], marker='o', label='Maximum Price')
plt.gca().yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)
plt.xlabel('Month and Year')
plt.ylabel('Price ($)')
plt.title('Pricing Trend (2023-2024)')
plt.legend()
plt.grid(True)

# %% [markdown]
# ### Q18. Which properties are currently unsold?

# %%
# List of properties which are unsold
query = """
    select 
        l.Listing_ID,
        l.City,
        l.Property_Type,
        l.Date_Listed
    from listings l
    left join sales s
    on l.Listing_ID = s.Listing_ID
    where s.Sale_Price is NULL;
"""
cur.execute(query)
result_18_1 = cur.fetchall()

# Define Headers
headers_18_1 = ['Listing_ID', 'City', 'Property_Type', 'Date_Listed']
print(tabulate(result_18_1, headers=headers_18_1, tablefmt='grid'))
# Out:
# +--------------+-------------+-----------------+---------------+
# | Listing_ID   | City        | Property_Type   | Date_Listed   |
# +==============+=============+=================+===============+
# | L00002       | Los Angeles | Apartment       | 2023-02-14    |
# +--------------+-------------+-----------------+---------------+
# | L00005       | Phoenix     | Townhouse       | 2023-10-29    |
# +--------------+-------------+-----------------+---------------+
# | L00009       | New York    | Townhouse       | 2024-05-13    |
# +--------------+-------------+-----------------+---------------+
# | L00014       | Chicago     | Apartment       | 2023-10-01    |
# +--------------+-------------+-----------------+---------------+
# | L00015       | Los Angeles | House           | 2023-05-19    |
# +--------------+-------------+-----------------+---------------+
# | L00016       | Phoenix     | House           | 2024-03-07    |
# ...

# %%
# Unsold Property Analysis

query = """
    select
        City,
        Property_Type,
        count(*) as Total_Unsold_Properties
    from
    (select 
        l.Listing_ID,
        l.City,
        l.Property_Type,
        l.Date_Listed
    from listings l
    left join sales s
    on l.Listing_ID = s.Listing_ID
    where s.Sale_Price is NULL) T
    group by
        City,
        Property_Type
    order by 
        city,
        Property_Type;
"""

cur.execute(query)
result_18_2 = cur.fetchall()

# Define Headers
headers_18_2 = ['City', 'Property_Type', 'Total_Unsold_Properties']
print(tabulate(result_18_2, headers=headers_18_2, tablefmt='grid'))
# Out:
# +-------------+-----------------+---------------------------+
# | City        | Property_Type   |   Total_Unsold_Properties |
# +=============+=================+===========================+
# | Chicago     | Apartment       |                      1017 |
# +-------------+-----------------+---------------------------+
# | Chicago     | Condo           |                      1046 |
# +-------------+-----------------+---------------------------+
# | Chicago     | House           |                      1063 |
# +-------------+-----------------+---------------------------+
# | Chicago     | Townhouse       |                      1011 |
# +-------------+-----------------+---------------------------+
# | Houston     | Apartment       |                      1028 |
# +-------------+-----------------+---------------------------+
# | Houston     | Condo           |                      1024 |
# +-------------+-----------------+---------------------------+
# ...

# %%
# Visualization

from matplotlib.pyplot import bar_label


df = pd.DataFrame(result_18_2, columns=headers_18_2)

plt.figure(figsize=(6, 5))
ax = sns.barplot(
    data=df,
    x='City',
    y='Total_Unsold_Properties',
    hue='Property_Type'
)

for container in ax.containers:
    bar_label(container, 
        label_type='center', 
        rotation=90,
        color='white'
    )

plt.ylim(0, 1700)
plt.title('Unsold Properties in each City')
plt.xlabel('City')
plt.ylabel('Number of Properties')
plt.show()

# %% [markdown]
# # Agent Performance

# %% [markdown]
# ### Q19. Which agents have closed the most sales?

# %%
# Top 10 Agents with Most Sales
query = """
    select
        *
    from(select
        dense_rank() over(
            order by Deals_Closed desc
        ) as Agent_Rank,
        Agent_ID,
        Deals_Closed as Total_Sales,
        Commission_Rate,
        Rating,
        Years_Of_Experience,
        Avg_Closing_Days
    from agents) T
    where Agent_Rank between 1 and 10;
"""

cur.execute(query)
result_19 = cur.fetchall()

# Define Headers
headers_19 = ['Agent_Rank', 'Agent_ID', 'Total_Sales', 'Commission_Rate', 'Rating', 'Years_Of_Experience', 'Avg_Closing_Days']
print(tabulate(result_19, headers=headers_19, tablefmt='grid'))
# Out:
# +--------------+------------+---------------+-------------------+----------+-----------------------+--------------------+
# |   Agent_Rank | Agent_ID   |   Total_Sales |   Commission_Rate |   Rating |   Years_Of_Experience |   Avg_Closing_Days |
# +==============+============+===============+===================+==========+=======================+====================+
# |            1 | A0003      |           297 |              2.85 |      3.6 |                    21 |                 83 |
# +--------------+------------+---------------+-------------------+----------+-----------------------+--------------------+
# |            2 | A0030      |           296 |              2.79 |      3.3 |                    13 |                 77 |
# +--------------+------------+---------------+-------------------+----------+-----------------------+--------------------+
# |            3 | A0010      |           292 |              2.14 |      3.4 |                    17 |                 90 |
# ...

# %%
# Visualization
df = pd.DataFrame(result_19, columns=headers_19)
#plt.figure(figsize=(10,6))
plt.bar(df['Agent_ID'], df['Total_Sales'])

for index, value in zip(df['Agent_ID'], df['Total_Sales']):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.xticks(rotation=45)
plt.ylim(0, 400)
plt.xlabel('Agent ID')
plt.ylabel('Sales')
plt.title('Number of properties sold by top 10 agents')
plt.show()

# %% [markdown]
# ### Q20. Who are the top agents by total sales revenue?

# %%
# Top 10 agents with highest total sales revenue
query = """
    select
        *
    from(select
        dense_rank() over(
            order by sum(s.Sale_Price) desc
        ) as Agent_Rank,
        l.Agent_ID,
        round(sum(s.Sale_Price), 2) as Total_Sales_Amount
    from sales s
    inner join listings l
    on s.Listing_ID=l.Listing_ID
    group by
        l.Agent_ID) T
    where Agent_Rank between 1 and 10;
"""

cur.execute(query)
result_20 = cur.fetchall()
headers_20 = ['Agent_Rank', 'Agent_ID', 'Total_Sales_Amount']
print(tabulate(result_20, headers=headers_20, tablefmt='grid'))
# Out:
# +--------------+------------+----------------------+
# |   Agent_Rank | Agent_ID   |   Total_Sales_Amount |
# +==============+============+======================+
# |            1 | A0011      |          2.78823e+07 |
# +--------------+------------+----------------------+
# |            2 | A0042      |          2.71916e+07 |
# +--------------+------------+----------------------+
# |            3 | A0043      |          2.41024e+07 |
# +--------------+------------+----------------------+
# |            4 | A0035      |          2.27258e+07 |
# +--------------+------------+----------------------+
# |            5 | A0014      |          2.2034e+07  |
# +--------------+------------+----------------------+
# |            6 | A0046      |          2.13358e+07 |
# +--------------+------------+----------------------+
# |            7 | A0048      |          2.11863e+07 |
# +--------------+------------+----------------------+
# |            8 | A0027      |          2.10997e+07 |
# ...

# %%
# Visualization
df = pd.DataFrame(result_20, columns=headers_20)
plt.bar(df['Agent_ID'], df['Total_Sales_Amount'])
plt.gca().yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)
plt.xticks(rotation=45)
plt.xlabel('Agent ID')
plt.ylabel('Price ($)')
plt.title('Top 10 Agents with most Total Sales Revenue')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Q21. Which agents close deals fastest?

# %%
# Top 10 agents with lowest average of closing a deal.
query = """
    select *
    from
    (select
        dense_rank() over(
            order by Avg_Closing_Days
        ) as Agent_Rank,
        Agent_ID,
        Avg_Closing_Days,
        Deals_Closed,
        Commission_Rate,
        Years_Of_Experience,
        Rating
    from agents) T
    where Agent_Rank between 1 and 10;
"""

cur.execute(query)
result_21_1 = cur.fetchall()
headers_21_1 = ['Agent_Rank', 'Agent_ID', 'Avg_Closing_Days', 'Deals_Closed', 'Commission_Rate', 'Years_Of_Experience', 'Rating']
print(tabulate(result_21_1, headers=headers_21_1, tablefmt='grid'))
# Out:
# +--------------+------------+--------------------+----------------+-------------------+-----------------------+----------+
# |   Agent_Rank | Agent_ID   |   Avg_Closing_Days |   Deals_Closed |   Commission_Rate |   Years_Of_Experience |   Rating |
# +==============+============+====================+================+===================+=======================+==========+
# |            1 | A0048      |                 15 |            266 |              1.34 |                    21 |      4   |
# +--------------+------------+--------------------+----------------+-------------------+-----------------------+----------+
# |            2 | A0035      |                 20 |            262 |              2.96 |                     1 |      3.4 |
# +--------------+------------+--------------------+----------------+-------------------+-----------------------+----------+
# |            3 | A0042      |                 21 |            231 |              2.24 |                    13 |      4.3 |
# ...

# %%
# Visualization
df = pd.DataFrame(result_21_1, columns=headers_21_1)
plt.bar(df['Agent_ID'], df['Avg_Closing_Days'])
#plt.barh(df['Avg_Closing_Days'], df['Agent_ID'])
plt.gca().yaxis.set_major_formatter(
    ticker.StrMethodFormatter('{x:,.0f}')
)

for index, value in zip(df['Agent_ID'], df['Avg_Closing_Days']):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.xticks(rotation=45)
plt.yticks(np.arange(0, 41, 5))
plt.xlabel('Agent ID')
plt.ylabel('Days')
plt.title('Agents with lowest average closing days')
plt.show()

# %%
# Agents recorded with the lowest closing day
query = """
    select 
        l.Agent_ID,
        s.Days_On_Market as Days_Taken,
        l.Listing_ID,
        l.Date_Listed,
        s.Date_Sold
    from listings l
    inner join sales s
    on l.Listing_ID = s.Listing_ID
    where 
        s.Days_On_Market = (select min(Days_On_Market) from sales)
    order by 
        l.Date_Listed;
"""

cur.execute(query)
result_21_2 = cur.fetchall()
headers_21_2 = ['Agent_ID', 'Days_Taken', 'Listing_ID', 'Date_Listed', 'Date_Sold']
print(tabulate(result_21_2, headers=headers_21_2, tablefmt='grid'))
# Out:
# +------------+--------------+--------------+---------------+-------------+
# | Agent_ID   |   Days_Taken | Listing_ID   | Date_Listed   | Date_Sold   |
# +============+==============+==============+===============+=============+
# | A0010      |            5 | L00994       | 2023-01-10    | 2023-01-15  |
# +------------+--------------+--------------+---------------+-------------+
# | A0019      |            5 | L00138       | 2023-02-17    | 2023-02-22  |
# +------------+--------------+--------------+---------------+-------------+
# | A0004      |            5 | L00819       | 2023-03-16    | 2023-03-21  |
# +------------+--------------+--------------+---------------+-------------+
# | A0017      |            5 | L00199       | 2023-08-24    | 2023-08-29  |
# +------------+--------------+--------------+---------------+-------------+
# | A0023      |            5 | L00788       | 2023-09-04    | 2023-09-09  |
# ...

# %% [markdown]
# ### Q22. Does experience correlate with deals closed?

# %%
query = """
    select 
        Years_Of_Experience,
        count(*) as Num_Of_Agents,
        round(avg(Deals_Closed), 0) as Avg_Deals_Closed
    from agents
    group by Years_Of_Experience
    order by Years_Of_Experience;
"""

cur.execute(query)
result_22_1 = cur.fetchall()
headers_22_1 = ['Years_Of_Experience', 'Num_Of_Agents', 'Avg_Deals_Closed']
print(tabulate(result_22_1, headers=headers_22_1, tablefmt='grid'))
# Out:
# +-----------------------+-----------------+--------------------+
# |   Years_Of_Experience |   Num_Of_Agents |   Avg_Deals_Closed |
# +=======================+=================+====================+
# |                     1 |               1 |                262 |
# +-----------------------+-----------------+--------------------+
# |                     2 |               1 |                 50 |
# +-----------------------+-----------------+--------------------+
# |                     3 |               1 |                 14 |
# +-----------------------+-----------------+--------------------+
# |                     4 |               2 |                140 |
# +-----------------------+-----------------+--------------------+
# |                     5 |               3 |                 88 |
# +-----------------------+-----------------+--------------------+
# |                     7 |               2 |                 73 |
# ...

# %%
# Visualization
df = pd.DataFrame(result_22_1, columns=headers_22_1)

plt.figure(figsize=(10,6))
plt.bar(df['Years_Of_Experience'], df['Avg_Deals_Closed'])

for index, value in zip(df['Years_Of_Experience'], df['Avg_Deals_Closed']):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.title('Average Sales Count Based on Agent Experience')
plt.xlabel('Years Of Exeprience')
plt.ylabel('Sales')
plt.show()

# %%
# Table to for correlation
query = """
    select 
        Years_Of_Experience,
        Deals_Closed
    from agents;
"""
cur.execute(query)
result_22_2 = cur.fetchall()
headers_22_2 = ['Years_Of_Experience', 'Deals_Closed']
df = pd.DataFrame(result_22_2, columns=headers_22_2)
sns.scatterplot(
    data=df,
    x='Years_Of_Experience',
    y='Deals_Closed'
)
plt.title('Agents with their Sales and Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ### Q23. Do agents with higher ratings close deals faster?

# %%
# Closing Days based on rating range
query = """
    select
        case
            when a.Rating between 1 and 2 then '1-2'
            when a.Rating between 2 and 3 then '2-3'
            when a.Rating between 3 and 4 then '3-4'
            when a.Rating between 4 and 5 then '4-5'
        end as Agent_Rating,
        round(avg(s.Days_On_Market), 0) as Avg_Closing_Days,
        min(s.Days_On_Market) as Lowest_Closing_Days,
        max(s.Days_On_Market) as Highest_Closing_Days,
        count(*) as Agent_Count
    from 
        sales s
    inner join listings l
    on s.Listing_ID = l.Listing_ID
    inner join agents a
    on l.Agent_ID = a.Agent_ID
    group by Agent_Rating;
"""
cur.execute(query)
result_23 = cur.fetchall()
headers_23 = ['Agent_Rating', 'Avg_Closing_Days', 'Lowest_Closing_Days', 'Highest_Closing_Days', 'Agent_Count']
print(tabulate(result_23, headers=headers_23, tablefmt='grid'))
# Out:
# +----------------+--------------------+-----------------------+------------------------+---------------+
# | Agent_Rating   |   Avg_Closing_Days |   Lowest_Closing_Days |   Highest_Closing_Days |   Agent_Count |
# +================+====================+=======================+========================+===============+
# | 3-4            |                 62 |                     5 |                    120 |           394 |
# +----------------+--------------------+-----------------------+------------------------+---------------+
# | 4-5            |                 62 |                     5 |                    120 |           326 |
# +----------------+--------------------+-----------------------+------------------------+---------------+

# %% [markdown]
# ### Q24. What is the average commission earned by each agent?

# %%
query = """
    select 
        l.Agent_ID,
        round(avg((a.Commission_Rate / 100) * s.Sale_Price), 2) as Avg_Commission_Earned
    from sales s
    inner join listings l
        on s.Listing_ID = l.Listing_ID
    inner join agents a
        on l.Agent_ID = a.Agent_ID
    group by l.Agent_ID
    order by Avg_Commission_Earned;
"""
cur.execute(query)
result_24 = cur.fetchall()
headers_24 = ['Agent_ID', 'Avg_Commission_Earned']
print(tabulate(result_24, headers=headers_24, tablefmt='grid'))
# Out:
# +------------+-------------------------+
# | Agent_ID   |   Avg_Commission_Earned |
# +============+=========================+
# | A0005      |                 11227   |
# +------------+-------------------------+
# | A0038      |                 11245   |
# +------------+-------------------------+
# | A0026      |                 11518   |
# +------------+-------------------------+
# | A0041      |                 12388.2 |
# +------------+-------------------------+
# | A0016      |                 13002   |
# +------------+-------------------------+
# | A0022      |                 13587.8 |
# +------------+-------------------------+
# | A0040      |                 14632.4 |
# +------------+-------------------------+
# | A0048      |                 14941.9 |
# +------------+-------------------------+
# | A0047      |                 15692.5 |
# +------------+-------------------------+
# | A0039      |                 16459.7 |
# +------------+-------------------------+
# ...

# %%
# Visualization
# Commission Distribution across agents
df = pd.DataFrame(result_24, columns=headers_24)
plt.figure(figsize=(10,15))
plt.barh(df['Agent_ID'], df['Avg_Commission_Earned'])

for index, value in enumerate(df['Avg_Commission_Earned']):
    plt.text(value, index, str(value), ha='right', va='center', color='white')

plt.title('Average Commission Earned by Agents for a Sale')
plt.xlabel('Amount ($)')
plt.ylabel('Agent ID')
plt.show()

# %%
# Box Plot
box = plt.boxplot(df['Avg_Commission_Earned'], patch_artist=True)
for patch in box['boxes']:
    patch.set_facecolor('#4C72B0') 
plt.ylabel("Average Commission Earned")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Q25. Which agents currently have the most active listings?

# %%
# Agents with most active listings
query = """
    select *
    from
        (select
            dense_rank() over(
                order by count(*) desc
            ) as Agent_Rank,
            Agent_ID,
            count(*) as Active_Property_Count
        from(
            select l.Agent_ID
            from listings l
            left join sales s
            on l.Listing_ID = s.Listing_ID
            where s.Date_Sold is not NULL) T1
        group by
            Agent_ID
        order by
            Active_Property_Count desc) T2
    where Agent_Rank between 1 and 10;
"""

cur.execute(query)
result_25 = cur.fetchall()
headers_25 = ['Agent_Rank', 'Agent_ID', 'Active_Property_Count']
print(tabulate(result_25, headers=headers_25, tablefmt='grid'))
# Out:
# +--------------+------------+-------------------------+
# |   Agent_Rank | Agent_ID   |   Active_Property_Count |
# +==============+============+=========================+
# |            1 | A0042      |                      25 |
# +--------------+------------+-------------------------+
# |            2 | A0011      |                      24 |
# +--------------+------------+-------------------------+
# |            3 | A0014      |                      21 |
# +--------------+------------+-------------------------+
# |            3 | A0035      |                      21 |
# +--------------+------------+-------------------------+
# |            4 | A0043      |                      20 |
# +--------------+------------+-------------------------+
# |            4 | A0046      |                      20 |
# +--------------+------------+-------------------------+
# |            5 | A0007      |                      19 |
# +--------------+------------+-------------------------+
# ...

# %%
# Visualization

df = pd.DataFrame(result_25, columns=headers_25)
df = df.sort_values(by='Active_Property_Count')

plt.figure(figsize=(10, 8))
plt.barh(df['Agent_ID'], df['Active_Property_Count'])

plt.xlabel('Number of Active Listings')
plt.ylabel('Agent ID')
plt.title('Top Agents by Number of Active Listings')

# add labels
for index, value in zip(df['Agent_ID'],df['Active_Property_Count']):
    plt.text(value, index, str(value), va='center')

plt.show()

# %% [markdown]
# # Buyer & Financing Behavior

# %% [markdown]
# ### Q26. What percentage of buyers are investors vs end users?

# %%
# Buyer Type Percentage
query = """
   select 
        Buyer_Type,
        round((100 * count(*) / (select count(*) from buyers)), 2) as Percentage
    from buyers
    group by
        Buyer_Type; 
"""
cur.execute(query)
result_26 = cur.fetchall()
headers_26 = ['Buyer_Type', 'Percentage']
print(tabulate(result_26, headers=headers_26, tablefmt='grid'))
# Out:
# +--------------+--------------+
# | Buyer_Type   |   Percentage |
# +==============+==============+
# | End User     |         50.1 |
# +--------------+--------------+
# | Investor     |         49.9 |
# +--------------+--------------+

# %%
# Visualization
df = pd.DataFrame(result_26, columns=headers_26)
fig, ax = plt.subplots()
ax.pie(df['Percentage'], labels=df['Buyer_Type'], autopct='%.2f%%')
plt.title('Buyer Type Percentage')
plt.show()

# %% [markdown]
# ### Q27. Which cities have the highest loan uptake rate?

# %%
# Loan Uptake Rate
query = """
    select
        dense_rank() OVER(
            ORDER BY round((100 * (T1.Count) / T2.Total_Buyers), 2) desc
        ) as City_Rank,
        T1.City,
        T1.Count,
        round((100 * (T1.Count) / T2.Total_Buyers), 2) as Percentage
    from
        (select 
            l.City,
            b.Loan_Taken,
            count(b.Loan_Taken) as Count
        from 
            buyers b
        inner join
            listings l
        on b.Listing_ID = l.Listing_ID
        group by
            l.City,
            b.Loan_Taken) T1
    inner join
        (select
            l.City,
            count(*) as Total_Buyers
        from 
            buyers b
        inner join
            listings l
        on b.Listing_ID = l.Listing_ID
        group by
            l.City) T2
    on T1.City = T2.City
    where Loan_Taken = True;
"""

cur.execute(query)
result_27 = cur.fetchall()
headers_27 = ['City_Rank', 'City', 'Count', 'Percentage']
print(tabulate(result_27, headers=headers_27, tablefmt='grid'))
# Out:
# +-------------+-------------+---------+--------------+
# |   City_Rank | City        |   Count |   Percentage |
# +=============+=============+=========+==============+
# |           1 | Los Angeles |    1811 |        50.99 |
# +-------------+-------------+---------+--------------+
# |           2 | Chicago     |    2188 |        50.57 |
# +-------------+-------------+---------+--------------+
# |           3 | New York    |    1913 |        50.22 |
# +-------------+-------------+---------+--------------+
# |           4 | Houston     |    1809 |        49.71 |
# +-------------+-------------+---------+--------------+
# |           5 | Phoenix     |    2313 |        49.5  |
# +-------------+-------------+---------+--------------+

# %% [markdown]
# ### Q28. What is the average loan amount by buyer type?

# %%
# Average loan amount by buyer type
query = """
    select
        Buyer_Type,
        round(avg(Loan_Amount), 2) as Avg_Loan_Amount
    from buyers
    where loan_taken = True
    group by
        Buyer_Type;
"""
cur.execute(query)
result_28 = cur.fetchall()
headers_28 = ['Buyer_Type', 'Avg_Loan_Amount']
print(tabulate(result_28, headers=headers_28, tablefmt='grid'))
# Out:
# +--------------+-------------------+
# | Buyer_Type   |   Avg_Loan_Amount |
# +==============+===================+
# | Investor     |       5.21155e+06 |
# +--------------+-------------------+
# | End User     |       5.21031e+06 |
# +--------------+-------------------+

# %% [markdown]
# ### Q29. Which payment mode is most commonly used?

# %%
# Most commonly used payment
query = """
    select
        dense_rank() over(
            order by (100 * count(*) / (select count(*) from buyers)) desc
        ) as Payment_Method_Rank,
        Payment_Method,
        count(*) as Count,
        (100 * count(*) / (select count(*) from buyers)) as Percentage
    from buyers
    group by
        Payment_Method;
"""
cur.execute(query)
result_29 = cur.fetchall()
headers_29 = ['Payment_Method_Rank', 'Payment_Method', 'Count', 'Percentage']
print(tabulate(result_29, headers=headers_29, tablefmt='grid'))
# Out:
# +-----------------------+------------------+---------+--------------+
# |   Payment_Method_Rank | Payment_Method   |   Count |   Percentage |
# +=======================+==================+=========+==============+
# |                     1 | Cash             |    5088 |       25.44  |
# +-----------------------+------------------+---------+--------------+
# |                     2 | UPI              |    5012 |       25.06  |
# +-----------------------+------------------+---------+--------------+
# |                     3 | Cheque           |    4951 |       24.755 |
# +-----------------------+------------------+---------+--------------+
# |                     4 | Bank Transfer    |    4949 |       24.745 |
# +-----------------------+------------------+---------+--------------+

# %%
# Visualization
df = pd.DataFrame(result_29, columns=headers_29)

fig, ax = plt.subplots()
ax.pie(df['Percentage'], labels=df['Payment_Method'], autopct='%.2f%%')
plt.title("Payment Methods Used by Buyers")
plt.show()

# %% [markdown]
# ### Q30. Do loan-backed purchases take longer to close?

# %%
# Closing Days comparison based on loan taken status
query = """
    select
        case
            when b.Loan_Taken = True then 'Yes'
            when b.Loan_Taken = False then 'No'
        end as Loan_Taken,
        count(*) as Count,
        round(avg(s.Days_On_Market), 0) as Avg_Days_On_Market,
        min(s.Days_On_Market) as Lowest_Days_On_Market,
        max(s.Days_On_Market) as Highest_Days_On_Market,
        round(stddev(s.Days_On_Market), 2) as Std_Deviation
    from sales s
    inner join
        buyers b
    on s.Listing_ID = b.Listing_ID
    group by
        b.Loan_Taken
    order by
        Avg_Days_On_Market desc;
"""
cur.execute(query)
result_30 = cur.fetchall()
headers_30 = ['Loan_Taken', 'Count', 'Avg_Days_On_Market', 'Lowest_Days_On_Market', 'Highest_Days_On_Market', 'Std_Deviation']
print(tabulate(result_30, headers=headers_30, tablefmt='grid'))
# Out:
# +--------------+---------+----------------------+-------------------------+--------------------------+-----------------+
# | Loan_Taken   |   Count |   Avg_Days_On_Market |   Lowest_Days_On_Market |   Highest_Days_On_Market |   Std_Deviation |
# +==============+=========+======================+=========================+==========================+=================+
# | Yes          |   10034 |                   62 |                       5 |                      120 |           34.15 |
# +--------------+---------+----------------------+-------------------------+--------------------------+-----------------+
# | No           |    9966 |                   61 |                       5 |                      120 |           34.03 |
# +--------------+---------+----------------------+-------------------------+--------------------------+-----------------+
